# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from bidict import bidict
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
ENCODER = bidict({
    'sa': 0,
    'da_ra': 1, 
    'ta': 2
})

# %%
labels = np.load("../data_cc3_1/labels.npy")
labels = labels - 1
labels.shape
# Out:
# (466,)

# %%
imgs = np.load("../data_cc3_1/imgs.npy").astype("float32") / 255

# %%
# check out one of the images
plt.figure()
plt.imshow(imgs[0])
plt.grid(False)
plt.show()

# %%
if imgs.ndim == 3:
    imgs = np.expand_dims(imgs, -1)

# %%
imgs_train, imgs_test, labels_train, labels_test = train_test_split(
    imgs, labels, test_size=0.20, stratify=labels, random_state=42
)

# %%
print(imgs_train.shape)
print(labels_train.shape)

print(labels_train.min())
print(labels_train.max())
# Out:
# (372, 50, 50, 1)
# (372,)
# 0
# 2

# %%
def add_noise(img):
    noise = tf.random.normal(shape=tf.shape(img), mean=0.0, stddev=0.05, dtype=tf.float32)
    return tf.clip_by_value(img + noise, 0.0, 1.0)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
)
datagen.fit(imgs_train)

# %%
for x_batch, y_batch in datagen.flow(imgs_train, labels_train, batch_size=4):
    for i in range(4):
        plt.subplot(1, 4, i+1)
        plt.imshow(x_batch[i].squeeze(), cmap='gray')
        plt.title(f"Label: {y_batch[i]}")
        plt.axis('off')
    plt.show()
    break

# %%
from tensorflow.keras import regularizers

batch_size = 8
epochs = 30

model = keras.Sequential([
    keras.Input(shape=(50, 50, 1)),

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(3, activation='softmax')
])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=4, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
# checkpoint = ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)

optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_train),
    y=labels_train
)

class_weight_dict = dict(enumerate(class_weights))

model.fit(
    datagen.flow(imgs_train, labels_train, batch_size=batch_size),
    epochs=epochs,
    validation_data=(imgs_test, labels_test),
    callbacks=[early_stopping, lr_scheduler],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# C:\Users\ASUS\Desktop\baybayin-ml\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6596 - loss: 0.7756 - val_accuracy: 0.3511 - val_loss: 1.2271 - learning_rate: 0.0010
# Epoch 2/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9586 - loss: 0.2397 - val_accuracy: 0.5532 - val_loss: 1.2270 - learning_rate: 0.0010
# Epoch 3/30
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9701 - loss: 0.2358
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9700 - loss: 0.2363 - val_accuracy: 0.3298 - val_loss: 1.2360 - learning_rate: 0.0010
# Epoch 4/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9727 - loss: 0.1875 - val_accuracy: 0.3298 - val_loss: 1.2473 - learning_rate: 5.0000e-04
# Epoch 5/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9845 - loss: 0.1729 - val_accuracy: 0.3298 - val_loss: 1.1790 - learning_rate: 5.0000e-04
# Epoch 6/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9531 - loss: 0.2753 - val_accuracy: 0.3298 - val_loss: 1.2110 - learning_rate: 5.0000e-04
# Epoch 7/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9826 - loss: 0.1870 - val_accuracy: 0.6489 - val_loss: 1.1470 - learning_rate: 5.0000e-04
# Epoch 8/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9807 - loss: 0.1582 - val_accuracy: 0.5957 - val_loss: 1.0805 - learning_rate: 5.0000e-04
# Epoch 9/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9830 - loss: 0.1480 - val_accuracy: 0.5213 - val_loss: 1.1767 - learning_rate: 5.0000e-04
# Epoch 10/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9512 - loss: 0.2085 - val_accuracy: 0.6489 - val_loss: 0.9008 - learning_rate: 5.0000e-04
# Epoch 11/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9905 - loss: 0.1228 - val_accuracy: 0.6596 - val_loss: 0.7149 - learning_rate: 5.0000e-04
# Epoch 12/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9977 - loss: 0.1158 - val_accuracy: 0.6915 - val_loss: 0.6299 - learning_rate: 5.0000e-04
# Epoch 13/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.1033 - val_accuracy: 0.9681 - val_loss: 0.2574 - learning_rate: 5.0000e-04
# Epoch 14/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9783 - loss: 0.1496 - val_accuracy: 0.9894 - val_loss: 0.1351 - learning_rate: 5.0000e-04
# Epoch 15/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9948 - loss: 0.1045 - val_accuracy: 1.0000 - val_loss: 0.0901 - learning_rate: 5.0000e-04
# Epoch 16/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9712 - loss: 0.1410 - val_accuracy: 1.0000 - val_loss: 0.0933 - learning_rate: 5.0000e-04
# Epoch 17/30
# 45/47 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9901 - loss: 0.1750
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9897 - loss: 0.1740 - val_accuracy: 1.0000 - val_loss: 0.0957 - learning_rate: 5.0000e-04
# Epoch 18/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9819 - loss: 0.1481 - val_accuracy: 1.0000 - val_loss: 0.0986 - learning_rate: 2.5000e-04
# Epoch 19/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9866 - loss: 0.1309 - val_accuracy: 1.0000 - val_loss: 0.0876 - learning_rate: 2.5000e-04
# Epoch 20/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9908 - loss: 0.1224 - val_accuracy: 1.0000 - val_loss: 0.0858 - learning_rate: 2.5000e-04
# Epoch 21/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9755 - loss: 0.1206 - val_accuracy: 1.0000 - val_loss: 0.0833 - learning_rate: 2.5000e-04
# Epoch 22/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9962 - loss: 0.1066 - val_accuracy: 1.0000 - val_loss: 0.0823 - learning_rate: 2.5000e-04
# Epoch 23/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0909 - val_accuracy: 1.0000 - val_loss: 0.0798 - learning_rate: 2.5000e-04
# Epoch 24/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9863 - loss: 0.1122 - val_accuracy: 1.0000 - val_loss: 0.0790 - learning_rate: 2.5000e-04
# Epoch 25/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0885 - val_accuracy: 1.0000 - val_loss: 0.0772 - learning_rate: 2.5000e-04
# Epoch 26/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9934 - loss: 0.0978 - val_accuracy: 1.0000 - val_loss: 0.0756 - learning_rate: 2.5000e-04
# Epoch 27/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9975 - loss: 0.0816 - val_accuracy: 1.0000 - val_loss: 0.0739 - learning_rate: 2.5000e-04
# Epoch 28/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9970 - loss: 0.0843 - val_accuracy: 1.0000 - val_loss: 0.0723 - learning_rate: 2.5000e-04
# Epoch 29/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0794 - val_accuracy: 1.0000 - val_loss: 0.0707 - learning_rate: 2.5000e-04
# Epoch 30/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9980 - loss: 0.0825 - val_accuracy: 1.0000 - val_loss: 0.0693 - learning_rate: 2.5000e-04

# %%
print(labels_train[:5])  # should be like: [0, 2, 1, 0, 1]
print(np.unique(labels_train))  # should show: [0 1 2]
# Out:
# [1 0 0 0 2]
# [0 1 2]

# %% [markdown]
# 32 128-3-2 256-3-2 .9102
# 32 256-3-2 128-3-2 .9077
# 32 128-3-2 256-3-2 512-3-2 .9127
# 32 128-1-2 256-3-2 512-5-2 .9327
# 32 128-5-2 256-5-2 512-5-2 .9626

# %%
model.evaluate(imgs_test, labels_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0692
# [0.0692729726433754, 1.0]

# %%
y_pred = model.predict(imgs_test)
y_pred_labels = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test, y_pred_labels)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=ENCODER.inverse, yticklabels=ENCODER.inverse)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
wrong = np.where(y_pred_labels != labels_test)[0]
for i in wrong[:5]:
    plt.imshow(imgs_test[i].squeeze(), cmap='gray')
    print(f"True: {ENCODER.inverse[labels_test[i]]}, Pred: {ENCODER.inverse[y_pred_labels[i]]}")
    plt.show()

# %%
import numpy as np

sample_imgs = imgs_test[:5]
sample_labels = labels_test[:5]

preds = model.predict(sample_imgs)
predicted_classes = np.argmax(preds, axis=1)

print("Predicted:", predicted_classes)
print("Actual:   ", sample_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted: [0 2 2 0 1]
# Actual:    [0 2 2 0 1]

# %%
import numpy as np
from collections import Counter

print("Train:", Counter(labels_train))
print("Test:", Counter(labels_test))
# Out:
# Train: Counter({np.int64(0): 130, np.int64(1): 121, np.int64(2): 121})
# Test: Counter({np.int64(0): 33, np.int64(1): 31, np.int64(2): 30})

# %%
y_pred = model.predict(imgs_test).argmax(axis=1)
cm = confusion_matrix(labels_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 24, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 22, 22, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 11, 11, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7744)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         495,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,544,843 (5.89 MB)
#  Trainable params: 514,883 (1.96 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 1,029,768 (3.93 MB)

# %%
model.save("model_cc3_2.keras")
