# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from bidict import bidict
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
ENCODER = bidict({
    'sa': 0,
    'da_ra': 1, 
    'ya': 2
})

# %%
labels = np.load("../data_cc3/labels.npy")
labels = labels - 1
labels.shape
# Out:
# (515,)

# %%
imgs = np.load("../data_cc3/imgs.npy").astype("float32") / 255

# %%
# check out one of the images
plt.figure()
plt.imshow(imgs[0])
plt.grid(False)
plt.show()

# %%
if imgs.ndim == 3:
    imgs = np.expand_dims(imgs, -1)

# %%
imgs_train, imgs_test, labels_train, labels_test = train_test_split(
    imgs, labels, test_size=0.20, stratify=labels, random_state=42
)

# %%
print(imgs_train.shape)
print(labels_train.shape)

print(labels_train.min())
print(labels_train.max())
# Out:
# (412, 50, 50, 1)
# (412,)
# 0
# 2

# %%
def add_noise(img):
    noise = tf.random.normal(shape=tf.shape(img), mean=0.0, stddev=0.05, dtype=tf.float32)
    return tf.clip_by_value(img + noise, 0.0, 1.0)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
)
datagen.fit(imgs_train)

# %%
for x_batch, y_batch in datagen.flow(imgs_train, labels_train, batch_size=4):
    for i in range(4):
        plt.subplot(1, 4, i+1)
        plt.imshow(x_batch[i].squeeze(), cmap='gray')
        plt.title(f"Label: {y_batch[i]}")
        plt.axis('off')
    plt.show()
    break

# %%
from tensorflow.keras import regularizers

batch_size = 8
epochs = 30

model = keras.Sequential([
    keras.Input(shape=(50, 50, 1)),

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(3, activation='softmax')
])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=4, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
# checkpoint = ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)

optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_train),
    y=labels_train
)

class_weight_dict = dict(enumerate(class_weights))

model.fit(
    datagen.flow(imgs_train, labels_train, batch_size=batch_size),
    epochs=epochs,
    validation_data=(imgs_test, labels_test),
    callbacks=[early_stopping, lr_scheduler],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# C:\Users\ASUS\Desktop\baybayin-ml\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6803 - loss: 0.8017 - val_accuracy: 0.2913 - val_loss: 1.2423 - learning_rate: 0.0010
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8867 - loss: 0.3995 - val_accuracy: 0.2913 - val_loss: 1.2423 - learning_rate: 0.0010
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9309 - loss: 0.3159 - val_accuracy: 0.6117 - val_loss: 1.2401 - learning_rate: 0.0010
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9231 - loss: 0.3416 - val_accuracy: 0.2913 - val_loss: 1.2360 - learning_rate: 0.0010
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9548 - loss: 0.2781 - val_accuracy: 0.3786 - val_loss: 1.1592 - learning_rate: 0.0010
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9495 - loss: 0.3477 - val_accuracy: 0.2913 - val_loss: 1.3147 - learning_rate: 0.0010
# Epoch 7/30
# 48/52 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9782 - loss: 0.2363
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9769 - loss: 0.2377 - val_accuracy: 0.3204 - val_loss: 1.3615 - learning_rate: 0.0010
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9766 - loss: 0.2297 - val_accuracy: 0.5437 - val_loss: 0.9517 - learning_rate: 5.0000e-04
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9687 - loss: 0.2906 - val_accuracy: 0.5437 - val_loss: 0.8909 - learning_rate: 5.0000e-04
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9569 - loss: 0.2684 - val_accuracy: 0.3883 - val_loss: 1.0670 - learning_rate: 5.0000e-04
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9902 - loss: 0.1673 - val_accuracy: 0.9417 - val_loss: 0.3339 - learning_rate: 5.0000e-04
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9717 - loss: 0.1909 - val_accuracy: 0.9806 - val_loss: 0.2610 - learning_rate: 5.0000e-04
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9790 - loss: 0.1751 - val_accuracy: 0.9903 - val_loss: 0.1756 - learning_rate: 5.0000e-04
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9767 - loss: 0.2176 - val_accuracy: 0.9903 - val_loss: 0.1642 - learning_rate: 5.0000e-04
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9928 - loss: 0.1487 - val_accuracy: 0.9903 - val_loss: 0.1927 - learning_rate: 5.0000e-04
# Epoch 16/30
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.1472
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9906 - loss: 0.1489 - val_accuracy: 0.9806 - val_loss: 0.2078 - learning_rate: 5.0000e-04
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9682 - loss: 0.1719 - val_accuracy: 0.9806 - val_loss: 0.1430 - learning_rate: 2.5000e-04
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9883 - loss: 0.1520 - val_accuracy: 0.9903 - val_loss: 0.1519 - learning_rate: 2.5000e-04
# Epoch 19/30
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9784 - loss: 0.1971
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9786 - loss: 0.1957 - val_accuracy: 0.9709 - val_loss: 0.1587 - learning_rate: 2.5000e-04
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9888 - loss: 0.1524 - val_accuracy: 0.9903 - val_loss: 0.1452 - learning_rate: 1.2500e-04
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9974 - loss: 0.1281
# Epoch 21: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9973 - loss: 0.1282 - val_accuracy: 0.9903 - val_loss: 0.1430 - learning_rate: 1.2500e-04
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9884 - loss: 0.1379 - val_accuracy: 0.9806 - val_loss: 0.1381 - learning_rate: 6.2500e-05
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9828 - loss: 0.1413 - val_accuracy: 0.9903 - val_loss: 0.1355 - learning_rate: 6.2500e-05
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9771 - loss: 0.1563 - val_accuracy: 0.9903 - val_loss: 0.1305 - learning_rate: 6.2500e-05
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9784 - loss: 0.1459 - val_accuracy: 0.9903 - val_loss: 0.1285 - learning_rate: 6.2500e-05
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9969 - loss: 0.1215 - val_accuracy: 0.9903 - val_loss: 0.1266 - learning_rate: 6.2500e-05
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9943 - loss: 0.1286 - val_accuracy: 0.9903 - val_loss: 0.1279 - learning_rate: 6.2500e-05
# Epoch 28/30
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9862 - loss: 0.1313
# Epoch 28: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9862 - loss: 0.1313 - val_accuracy: 0.9903 - val_loss: 0.1308 - learning_rate: 6.2500e-05
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9934 - loss: 0.1182 - val_accuracy: 0.9903 - val_loss: 0.1307 - learning_rate: 3.1250e-05
# Epoch 30/30
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9853 - loss: 0.1367
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9855 - loss: 0.1362 - val_accuracy: 0.9903 - val_loss: 0.1318 - learning_rate: 3.1250e-05

# %%
print(labels_train[:5])  # should be like: [0, 2, 1, 0, 1]
print(np.unique(labels_train))  # should show: [0 1 2]
# Out:
# [2 1 1 0 2]
# [0 1 2]

# %% [markdown]
# 32 128-3-2 256-3-2 .9102
# 32 256-3-2 128-3-2 .9077
# 32 128-3-2 256-3-2 512-3-2 .9127
# 32 128-1-2 256-3-2 512-5-2 .9327
# 32 128-5-2 256-5-2 512-5-2 .9626

# %%
model.evaluate(imgs_test, labels_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9909 - loss: 0.1285
# [0.12657496333122253, 0.9902912378311157]

# %%
y_pred = model.predict(imgs_test)
y_pred_labels = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test, y_pred_labels)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=ENCODER.inverse, yticklabels=ENCODER.inverse)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
wrong = np.where(y_pred_labels != labels_test)[0]
for i in wrong[:5]:
    plt.imshow(imgs_test[i].squeeze(), cmap='gray')
    print(f"True: {ENCODER.inverse[labels_test[i]]}, Pred: {ENCODER.inverse[y_pred_labels[i]]}")
    plt.show()
# Out:
# True: sa, Pred: ya

# %%
import numpy as np

sample_imgs = imgs_test[:5]
sample_labels = labels_test[:5]

preds = model.predict(sample_imgs)
predicted_classes = np.argmax(preds, axis=1)

print("Predicted:", predicted_classes)
print("Actual:   ", sample_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted: [2 2 1 1 1]
# Actual:    [2 2 1 1 1]

# %%
import numpy as np
from collections import Counter

print("Train:", Counter(labels_train))
print("Test:", Counter(labels_test))
# Out:
# Train: Counter({np.int64(2): 160, np.int64(0): 130, np.int64(1): 122})
# Test: Counter({np.int64(2): 40, np.int64(0): 33, np.int64(1): 30})

# %%
y_pred = model.predict(imgs_test).argmax(axis=1)
cm = confusion_matrix(labels_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 24, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 22, 22, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 11, 11, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7744)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         495,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,544,843 (5.89 MB)
#  Trainable params: 514,883 (1.96 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 1,029,768 (3.93 MB)

# %%
model.save("model_cc3_1.keras")
