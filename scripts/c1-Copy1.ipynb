# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from bidict import bidict
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
ENCODER = bidict({
    'ha': 0, 
    'pa' : 1,
    'ka': 2
})

# %%
labels = np.load("../data_c1/labels.npy")
labels = labels - 1
labels.shape
# Out:
# (459,)

# %%
imgs = np.load("../data_c1/imgs.npy").astype("float32") / 255

# %%
# check out one of the images
plt.figure()
plt.imshow(imgs[0])
plt.grid(False)
plt.show()

# %%
if imgs.ndim == 3:
    imgs = np.expand_dims(imgs, -1)

# %%
imgs_train, imgs_test, labels_train, labels_test = train_test_split(
    imgs, labels, test_size=0.30, stratify=labels, random_state=42
)

# %%
print(imgs_train.shape)
print(labels_train.shape)

print(labels_train.min())
print(labels_train.max())
# Out:
# (321, 50, 50, 1)
# (321,)
# 0
# 2

# %%
def add_noise(img):
    noise = tf.random.normal(shape=tf.shape(img), mean=0.0, stddev=0.05, dtype=tf.float32)
    return tf.clip_by_value(img + noise, 0.0, 1.0)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1
)
datagen.fit(imgs_train)

# %%
for x_batch, y_batch in datagen.flow(imgs_train, labels_train, batch_size=4):
    for i in range(4):
        plt.subplot(1, 4, i+1)
        plt.imshow(x_batch[i].squeeze(), cmap='gray')
        plt.title(f"Label: {y_batch[i]}")
        plt.axis('off')
    plt.show()
    break

# %%
batch_size = 8
epochs = 30

model = keras.Sequential([
    keras.Input(shape=(50, 50, 1)),

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3, activation='softmax')
])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=4, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
# checkpoint = ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)

optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_train),
    y=labels_train
)

class_weight_dict = dict(enumerate(class_weights))

model.fit(
    datagen.flow(imgs_train, labels_train, batch_size=batch_size),
    epochs=epochs,
    validation_data=(imgs_test, labels_test),
    callbacks=[early_stopping, lr_scheduler],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# C:\Users\ASUS\Desktop\baybayin-ml\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6400 - loss: 0.6511 - val_accuracy: 0.2609 - val_loss: 1.2615 - learning_rate: 0.0010
# Epoch 2/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8486 - loss: 0.3235 - val_accuracy: 0.2609 - val_loss: 1.2348 - learning_rate: 0.0010
# Epoch 3/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8911 - loss: 0.2292 - val_accuracy: 0.2609 - val_loss: 1.2973 - learning_rate: 0.0010
# Epoch 4/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8539 - loss: 0.2732
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8548 - loss: 0.2721 - val_accuracy: 0.2609 - val_loss: 1.2887 - learning_rate: 0.0010
# Epoch 5/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9255 - loss: 0.1499 - val_accuracy: 0.2609 - val_loss: 1.1560 - learning_rate: 5.0000e-04
# Epoch 6/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9067 - loss: 0.1625 - val_accuracy: 0.2609 - val_loss: 1.0910 - learning_rate: 5.0000e-04
# Epoch 7/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9559 - loss: 0.1228 - val_accuracy: 0.7029 - val_loss: 0.9785 - learning_rate: 5.0000e-04
# Epoch 8/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9502 - loss: 0.1194 - val_accuracy: 0.5580 - val_loss: 0.9476 - learning_rate: 5.0000e-04
# Epoch 9/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9561 - loss: 0.1249 - val_accuracy: 0.3188 - val_loss: 0.9228 - learning_rate: 5.0000e-04
# Epoch 10/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9517 - loss: 0.1117 - val_accuracy: 0.3188 - val_loss: 0.9209 - learning_rate: 5.0000e-04
# Epoch 11/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9636 - loss: 0.1140 - val_accuracy: 0.5145 - val_loss: 0.7644 - learning_rate: 5.0000e-04
# Epoch 12/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9549 - loss: 0.1223 - val_accuracy: 0.3188 - val_loss: 1.1944 - learning_rate: 5.0000e-04
# Epoch 13/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9610 - loss: 0.1121 - val_accuracy: 0.7681 - val_loss: 0.5628 - learning_rate: 5.0000e-04
# Epoch 14/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9813 - loss: 0.0914 - val_accuracy: 0.9493 - val_loss: 0.1952 - learning_rate: 5.0000e-04
# Epoch 15/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9789 - loss: 0.0839 - val_accuracy: 0.9783 - val_loss: 0.1339 - learning_rate: 5.0000e-04
# Epoch 16/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9644 - loss: 0.0877 - val_accuracy: 0.9710 - val_loss: 0.1086 - learning_rate: 5.0000e-04
# Epoch 17/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9463 - loss: 0.1270 - val_accuracy: 0.6812 - val_loss: 1.5701 - learning_rate: 5.0000e-04
# Epoch 18/30
# 38/41 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9579 - loss: 0.0761
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9586 - loss: 0.0757 - val_accuracy: 0.6812 - val_loss: 1.2866 - learning_rate: 5.0000e-04
# Epoch 19/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9830 - loss: 0.0464 - val_accuracy: 0.9638 - val_loss: 0.0776 - learning_rate: 2.5000e-04
# Epoch 20/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9806 - loss: 0.0491 - val_accuracy: 0.9783 - val_loss: 0.0443 - learning_rate: 2.5000e-04
# Epoch 21/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9818 - loss: 0.0612 - val_accuracy: 0.9855 - val_loss: 0.0333 - learning_rate: 2.5000e-04
# Epoch 22/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9999 - loss: 0.0278 - val_accuracy: 0.9783 - val_loss: 0.0451 - learning_rate: 2.5000e-04
# Epoch 23/30
# 39/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9664 - loss: 0.0729
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9668 - loss: 0.0721 - val_accuracy: 0.9710 - val_loss: 0.0536 - learning_rate: 2.5000e-04
# Epoch 24/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9659 - loss: 0.0748 - val_accuracy: 0.9855 - val_loss: 0.0286 - learning_rate: 1.2500e-04
# Epoch 25/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9854 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 0.0142 - learning_rate: 1.2500e-04
# Epoch 26/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9525 - loss: 0.0623 - val_accuracy: 0.9855 - val_loss: 0.0222 - learning_rate: 1.2500e-04
# Epoch 27/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9904 - loss: 0.0364 - val_accuracy: 1.0000 - val_loss: 0.0082 - learning_rate: 1.2500e-04
# Epoch 28/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9766 - loss: 0.0597 - val_accuracy: 1.0000 - val_loss: 0.0060 - learning_rate: 1.2500e-04
# Epoch 29/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9864 - loss: 0.0493 - val_accuracy: 1.0000 - val_loss: 0.0062 - learning_rate: 1.2500e-04
# Epoch 30/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9929 - loss: 0.0286 - val_accuracy: 1.0000 - val_loss: 0.0050 - learning_rate: 1.2500e-04

# %% [markdown]
# 32 128-3-2 256-3-2 .9102
# 32 256-3-2 128-3-2 .9077
# 32 128-3-2 256-3-2 512-3-2 .9127
# 32 128-1-2 256-3-2 512-5-2 .9327
# 32 128-5-2 256-5-2 512-5-2 .9626

# %%
model.evaluate(imgs_test, labels_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 1.0000 - loss: 0.0047
# [0.005000687669962645, 1.0]

# %%
y_pred = model.predict(imgs_test)
y_pred_labels = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test, y_pred_labels)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=ENCODER.inverse, yticklabels=ENCODER.inverse)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
wrong = np.where(y_pred_labels != labels_test)[0]
for i in wrong[:5]:
    plt.imshow(imgs_test[i].squeeze(), cmap='gray')
    print(f"True: {ENCODER.inverse[labels_test[i]]}, Pred: {ENCODER.inverse[y_pred_labels[i]]}")
    plt.show()

# %%
import numpy as np

sample_imgs = imgs_test[:5]
sample_labels = labels_test[:5]

preds = model.predict(sample_imgs)
predicted_classes = np.argmax(preds, axis=1)

print("Predicted:", predicted_classes)
print("Actual:   ", sample_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Predicted: [0 0 0 2 1]
# Actual:    [0 0 0 2 1]

# %%
import numpy as np
from collections import Counter

print("Train:", Counter(labels_train))
print("Test:", Counter(labels_test))
# Out:
# Train: Counter({np.int64(1): 134, np.int64(0): 102, np.int64(2): 85})
# Test: Counter({np.int64(1): 58, np.int64(0): 44, np.int64(2): 36})

# %%
y_pred = model.predict(imgs_test).argmax(axis=1)
cm = confusion_matrix(labels_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
import matplotlib.pyplot as plt

# Predict on test set
preds = model.predict(imgs_test)
pred_labels = np.argmax(preds, axis=1)

# Number of samples to show
num_samples = 10

# Inverse mapping from label to character
inv_encoder = {v: k for k, v in ENCODER.items()}

plt.figure(figsize=(15, 5))

for i in range(num_samples):
    plt.subplot(2, 5, i + 1)
    plt.imshow(imgs_test[i].squeeze(), cmap='gray')
    plt.axis('off')
    
    actual = inv_encoder[labels_test[i]]
    predicted = inv_encoder[pred_labels[i]]
    
    color = 'green' if actual == predicted else 'red'
    plt.title(f"Pred: {predicted}\nTrue: {actual}", color=color)

plt.tight_layout()
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
# Get predicted class indices
pred_labels = np.argmax(preds, axis=1)

# Find indices where prediction != true label
wrong_indices = np.where(pred_labels != labels_test)[0]

# Show the misclassified samples
for idx in wrong_indices:
    print(f"Index: {idx}")
    plt.imshow(imgs_test[idx].squeeze(), cmap='gray')
    true_lbl = ENCODER.inverse[labels_test[idx]]
    pred_lbl = ENCODER.inverse[pred_labels[idx]]
    plt.title(f"True: {true_lbl}, Pred: {pred_lbl}")
    plt.axis('off')
    plt.show()

# %%
# Load saved filenames
filenames = np.load("../data_c1/filenames.npy")

# Use the same split as your images
_, filenames_test = train_test_split(
    filenames, test_size=0.30, stratify=labels, random_state=42
)

# Then get the filename for index 8
print("File of misclassified image:", filenames_test[8])
# Out:
# File of misclassified image: pa.jcT9-Neil.jpg

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 24, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 22, 22, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 11, 11, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7744)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         495,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,544,843 (5.89 MB)
#  Trainable params: 514,883 (1.96 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 1,029,768 (3.93 MB)

# %%
unique, counts = np.unique(labels_train, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Label {u}: {c} samples")
# Out:
# Label 0: 102 samples
# Label 1: 134 samples
# Label 2: 85 samples

# %%
model.save("model_c1_2.keras")

# %%
print(f"Num classes: {len(np.unique(labels))}")
print(f"Min label: {np.min(labels)}, Max label: {np.max(labels)}")

# %%
import collections
print(collections.Counter(labels_train))

# %%
for i in range(10):
    sample = imgs_test[i].reshape(1, 50, 50, 1)
    pred = np.argmax(model.predict(sample), axis=-1)[0]
    true = labels_test[i]
    print(f"True: {true}, Pred: {pred}")
