# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from bidict import bidict
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
ENCODER = bidict({
    'ma': 0,
    'ya': 1, 
})

# %%
labels = np.load("../data_cc5_1/labels.npy")
labels = labels - 1
labels.shape
# Out:
# (346,)

# %%
imgs = np.load("../data_cc5_1/imgs.npy").astype("float32") / 255

# %%
# check out one of the images
plt.figure()
plt.imshow(imgs[0])
plt.grid(False)
plt.show()

# %%
if imgs.ndim == 3:
    imgs = np.expand_dims(imgs, -1)

# %%
imgs_train, imgs_test, labels_train, labels_test = train_test_split(
    imgs, labels, test_size=0.10, stratify=labels, random_state=42
)

# %%
print(imgs_train.shape)
print(labels_train.shape)

print(labels_train.min())
print(labels_train.max())
# Out:
# (311, 50, 50, 1)
# (311,)
# 0
# 1

# %%
def add_noise(img):
    noise = tf.random.normal(shape=tf.shape(img), mean=0.0, stddev=0.05, dtype=tf.float32)
    return tf.clip_by_value(img + noise, 0.0, 1.0)

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
)
datagen.fit(imgs_train)

# %%
for x_batch, y_batch in datagen.flow(imgs_train, labels_train, batch_size=4):
    for i in range(4):
        plt.subplot(1, 4, i+1)
        plt.imshow(x_batch[i].squeeze(), cmap='gray')
        plt.title(f"Label: {y_batch[i]}")
        plt.axis('off')
    plt.show()
    break

# %%
from tensorflow.keras import regularizers

batch_size = 8
epochs = 30

model = keras.Sequential([
    keras.Input(shape=(50, 50, 1)),

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')
])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=4, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)

early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
# checkpoint = ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)

optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,
              loss=loss_fn,
              metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_train),
    y=labels_train
)

class_weight_dict = dict(enumerate(class_weights))

model.fit(
    datagen.flow(imgs_train, labels_train, batch_size=batch_size),
    epochs=epochs,
    validation_data=(imgs_test, labels_test),
    callbacks=[early_stopping, lr_scheduler],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# C:\Users\ASUS\Desktop\baybayin-ml\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6547 - loss: 0.6980 - val_accuracy: 0.5714 - val_loss: 0.8045 - learning_rate: 0.0010
# Epoch 2/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9318 - loss: 0.3222 - val_accuracy: 0.5714 - val_loss: 0.7995 - learning_rate: 0.0010
# Epoch 3/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9310 - loss: 0.3456 - val_accuracy: 0.5714 - val_loss: 0.8007 - learning_rate: 0.0010
# Epoch 4/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9751 - loss: 0.2043 - val_accuracy: 0.5714 - val_loss: 0.7900 - learning_rate: 0.0010
# Epoch 5/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9705 - loss: 0.1871 - val_accuracy: 0.4286 - val_loss: 0.7877 - learning_rate: 0.0010
# Epoch 6/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9654 - loss: 0.1881 - val_accuracy: 0.4286 - val_loss: 0.7879 - learning_rate: 0.0010
# Epoch 7/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9909 - loss: 0.1498 - val_accuracy: 0.6000 - val_loss: 0.7746 - learning_rate: 0.0010
# Epoch 8/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9592 - loss: 0.1866 - val_accuracy: 0.5714 - val_loss: 0.7636 - learning_rate: 0.0010
# Epoch 9/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9843 - loss: 0.1294 - val_accuracy: 0.5714 - val_loss: 0.7284 - learning_rate: 0.0010
# Epoch 10/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9922 - loss: 0.1200 - val_accuracy: 0.5714 - val_loss: 0.6690 - learning_rate: 0.0010
# Epoch 11/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9888 - loss: 0.1127 - val_accuracy: 0.5714 - val_loss: 0.7759 - learning_rate: 0.0010
# Epoch 12/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9913 - loss: 0.1093 - val_accuracy: 0.5714 - val_loss: 0.6209 - learning_rate: 0.0010
# Epoch 13/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9910 - loss: 0.1146 - val_accuracy: 0.8286 - val_loss: 0.5247 - learning_rate: 0.0010
# Epoch 14/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9976 - loss: 0.0947 - val_accuracy: 0.5714 - val_loss: 0.5974 - learning_rate: 0.0010
# Epoch 15/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9936 - loss: 0.1002 - val_accuracy: 0.7143 - val_loss: 0.4068 - learning_rate: 0.0010
# Epoch 16/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 1.0000 - loss: 0.0856 - val_accuracy: 1.0000 - val_loss: 0.1085 - learning_rate: 0.0010
# Epoch 17/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9912 - loss: 0.1076 - val_accuracy: 1.0000 - val_loss: 0.1090 - learning_rate: 0.0010
# Epoch 18/30
# 35/39 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9977 - loss: 0.0886
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9967 - loss: 0.0905 - val_accuracy: 0.9714 - val_loss: 0.1659 - learning_rate: 0.0010
# Epoch 19/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9874 - loss: 0.0906 - val_accuracy: 1.0000 - val_loss: 0.0837 - learning_rate: 5.0000e-04
# Epoch 20/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9932 - loss: 0.0869 - val_accuracy: 1.0000 - val_loss: 0.0780 - learning_rate: 5.0000e-04
# Epoch 21/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9943 - loss: 0.0836 - val_accuracy: 1.0000 - val_loss: 0.0710 - learning_rate: 5.0000e-04
# Epoch 22/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9951 - loss: 0.0828 - val_accuracy: 1.0000 - val_loss: 0.0684 - learning_rate: 5.0000e-04
# Epoch 23/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9821 - loss: 0.1328 - val_accuracy: 1.0000 - val_loss: 0.0663 - learning_rate: 5.0000e-04
# Epoch 24/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9975 - loss: 0.0793 - val_accuracy: 1.0000 - val_loss: 0.0646 - learning_rate: 5.0000e-04
# Epoch 25/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0661 - val_accuracy: 1.0000 - val_loss: 0.0621 - learning_rate: 5.0000e-04
# Epoch 26/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9880 - loss: 0.0793 - val_accuracy: 1.0000 - val_loss: 0.0609 - learning_rate: 5.0000e-04
# Epoch 27/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 1.0000 - loss: 0.0636 - val_accuracy: 1.0000 - val_loss: 0.0589 - learning_rate: 5.0000e-04
# Epoch 28/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9972 - loss: 0.0641 - val_accuracy: 1.0000 - val_loss: 0.0578 - learning_rate: 5.0000e-04
# Epoch 29/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9915 - loss: 0.0942 - val_accuracy: 1.0000 - val_loss: 0.0577 - learning_rate: 5.0000e-04
# Epoch 30/30
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9943 - loss: 0.0838 - val_accuracy: 1.0000 - val_loss: 0.0571 - learning_rate: 5.0000e-04

# %%
print(labels_train[:5])  # should be like: [0, 2, 1, 0, 1]
print(np.unique(labels_train))  # should show: [0 1 2]
# Out:
# [0 1 1 1 0]
# [0 1]

# %% [markdown]
# 32 128-3-2 256-3-2 .9102
# 32 256-3-2 128-3-2 .9077
# 32 128-3-2 256-3-2 512-3-2 .9127
# 32 128-1-2 256-3-2 512-5-2 .9327
# 32 128-5-2 256-5-2 512-5-2 .9626

# %%
model.evaluate(imgs_test, labels_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0571
# [0.05708998441696167, 1.0]

# %%
y_pred = model.predict(imgs_test)
y_pred_labels = np.argmax(y_pred, axis=1)

cm = confusion_matrix(labels_test, y_pred_labels)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=ENCODER.inverse, yticklabels=ENCODER.inverse)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step

# %%
wrong = np.where(y_pred_labels != labels_test)[0]
for i in wrong[:5]:
    plt.imshow(imgs_test[i].squeeze(), cmap='gray')
    print(f"True: {ENCODER.inverse[labels_test[i]]}, Pred: {ENCODER.inverse[y_pred_labels[i]]}")
    plt.show()

# %%
import numpy as np

sample_imgs = imgs_test[:5]
sample_labels = labels_test[:5]

preds = model.predict(sample_imgs)
predicted_classes = np.argmax(preds, axis=1)

print("Predicted:", predicted_classes)
print("Actual:   ", sample_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted: [1 0 1 1 1]
# Actual:    [1 0 1 1 1]

# %%
import numpy as np
from collections import Counter

print("Train:", Counter(labels_train))
print("Test:", Counter(labels_test))
# Out:
# Train: Counter({np.int64(1): 180, np.int64(0): 131})
# Test: Counter({np.int64(1): 20, np.int64(0): 15})

# %%
y_pred = model.predict(imgs_test).argmax(axis=1)
cm = confusion_matrix(labels_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 24, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 22, 22, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 11, 11, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7744)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         495,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,544,648 (5.89 MB)
#  Trainable params: 514,818 (1.96 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 1,029,638 (3.93 MB)

# %%
model.save("model_cc5_2.keras")
