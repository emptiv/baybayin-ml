# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from bidict import bidict
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
ENCODER = bidict({
    'ha': 0, 
    'pa' : 1,
    'ka': 2
})

# %%
labels = np.load("../data_c1/labels.npy")
labels = labels - 1
labels.shape
# Out:
# (460,)

# %%
imgs = np.load("../data_c1/imgs.npy").astype("float32") / 255

# %%
# check out one of the images
plt.figure()
plt.imshow(imgs[0])
plt.grid(False)
plt.show()

# %%
if imgs.ndim == 3:
    imgs = np.expand_dims(imgs, -1)

# %%
imgs_train, imgs_test, labels_train, labels_test = train_test_split(
    imgs, labels, test_size=0.30, stratify=labels, random_state=42
)

# %%
print(imgs_train.shape)
print(labels_train.shape)

print(labels_train.min())
print(labels_train.max())
# Out:
# (322, 50, 50, 1)
# (322,)
# 0
# 2

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=5,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.1
)
datagen.fit(imgs_train)

# %%
for x_batch, y_batch in datagen.flow(imgs_train, labels_train, batch_size=4):
    for i in range(4):
        plt.subplot(1, 4, i+1)
        plt.imshow(x_batch[i].squeeze(), cmap='gray')
        plt.title(f"Label: {y_batch[i]}")
        plt.axis('off')
    plt.show()
    break

# %%
batch_size = 8
epochs = 30

model = keras.Sequential([
    keras.Input(shape=(50, 50, 1)),

    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.BatchNormalization(),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(3, activation='softmax')
])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=4, restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=2
)

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

early_stop = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
# checkpoint = ModelCheckpoint("best_model.keras", monitor="val_accuracy", save_best_only=True)

optimizer = keras.optimizers.Adam()

model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_train),
    y=labels_train
)

class_weight_dict = dict(enumerate(class_weights))

model.fit(
    datagen.flow(imgs_train, labels_train, batch_size=batch_size),
    epochs=epochs,
    validation_data=(imgs_test, labels_test),
    callbacks=[early_stopping, lr_scheduler],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/30
# C:\Users\ASUS\Desktop\baybayin-ml\venv\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7067 - loss: 0.5753 - val_accuracy: 0.2609 - val_loss: 1.2030 - learning_rate: 0.0010
# Epoch 2/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8816 - loss: 0.2832 - val_accuracy: 0.2609 - val_loss: 1.1895 - learning_rate: 0.0010
# Epoch 3/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8817 - loss: 0.2319 - val_accuracy: 0.2609 - val_loss: 1.1285 - learning_rate: 0.0010
# Epoch 4/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9226 - loss: 0.2014 - val_accuracy: 0.2609 - val_loss: 1.1611 - learning_rate: 0.0010
# Epoch 5/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9510 - loss: 0.1387 - val_accuracy: 0.5797 - val_loss: 1.0744 - learning_rate: 0.0010
# Epoch 6/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9036 - loss: 0.1777 - val_accuracy: 0.6812 - val_loss: 1.0231 - learning_rate: 0.0010
# Epoch 7/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9338 - loss: 0.1563 - val_accuracy: 0.3188 - val_loss: 0.9903 - learning_rate: 0.0010
# Epoch 8/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9358 - loss: 0.1893 - val_accuracy: 0.3188 - val_loss: 1.4505 - learning_rate: 0.0010
# Epoch 9/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9370 - loss: 0.1347 - val_accuracy: 0.5652 - val_loss: 0.8612 - learning_rate: 0.0010
# Epoch 10/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9607 - loss: 0.1124 - val_accuracy: 0.4203 - val_loss: 0.8734 - learning_rate: 0.0010
# Epoch 11/30
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9609 - loss: 0.0861
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9608 - loss: 0.0864 - val_accuracy: 0.3188 - val_loss: 1.2664 - learning_rate: 0.0010
# Epoch 12/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9685 - loss: 0.0752 - val_accuracy: 0.6014 - val_loss: 0.9215 - learning_rate: 5.0000e-04
# Epoch 13/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9869 - loss: 0.0638 - val_accuracy: 0.6957 - val_loss: 0.8049 - learning_rate: 5.0000e-04
# Epoch 14/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9896 - loss: 0.0458 - val_accuracy: 0.8768 - val_loss: 0.4037 - learning_rate: 5.0000e-04
# Epoch 15/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9809 - loss: 0.0416 - val_accuracy: 0.9928 - val_loss: 0.1092 - learning_rate: 5.0000e-04
# Epoch 16/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9814 - loss: 0.0567 - val_accuracy: 0.9203 - val_loss: 0.2391 - learning_rate: 5.0000e-04
# Epoch 17/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9947 - loss: 0.0310
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9945 - loss: 0.0313 - val_accuracy: 0.9420 - val_loss: 0.1627 - learning_rate: 5.0000e-04
# Epoch 18/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9920 - loss: 0.0215 - val_accuracy: 0.9638 - val_loss: 0.1026 - learning_rate: 2.5000e-04
# Epoch 19/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9924 - loss: 0.0461 - val_accuracy: 0.9203 - val_loss: 0.2247 - learning_rate: 2.5000e-04
# Epoch 20/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9829 - loss: 0.0370 - val_accuracy: 0.9928 - val_loss: 0.0342 - learning_rate: 2.5000e-04
# Epoch 21/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.9928 - val_loss: 0.0142 - learning_rate: 2.5000e-04
# Epoch 22/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9631 - loss: 0.0534 - val_accuracy: 0.9928 - val_loss: 0.0162 - learning_rate: 2.5000e-04
# Epoch 23/30
# 37/41 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 1.0000 - loss: 0.0104
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9928 - val_loss: 0.0151 - learning_rate: 2.5000e-04
# Epoch 24/30
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9955 - loss: 0.0271 - val_accuracy: 0.9928 - val_loss: 0.0166 - learning_rate: 1.2500e-04
# Epoch 25/30
# 40/41 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9945 - loss: 0.0206
# Epoch 25: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9943 - loss: 0.0212 - val_accuracy: 0.9928 - val_loss: 0.0274 - learning_rate: 1.2500e-04

# %% [markdown]
# 32 128-3-2 256-3-2 .9102
# 32 256-3-2 128-3-2 .9077
# 32 128-3-2 256-3-2 512-3-2 .9127
# 32 128-1-2 256-3-2 512-5-2 .9327
# 32 128-5-2 256-5-2 512-5-2 .9626

# %%
model.evaluate(imgs_test, labels_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9867 - loss: 0.0232
# [0.014247193932533264, 0.9927536249160767]

# %%
import numpy as np

sample_imgs = imgs_test[:5]
sample_labels = labels_test[:5]

preds = model.predict(sample_imgs)
predicted_classes = np.argmax(preds, axis=1)

print("Predicted:", predicted_classes)
print("Actual:   ", sample_labels)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Predicted: [0 0 0 2 1]
# Actual:    [0 0 0 2 1]

# %%
import numpy as np
from collections import Counter

print("Train:", Counter(labels_train))
print("Test:", Counter(labels_test))
# Out:
# Train: Counter({np.int32(1): 135, np.int32(0): 102, np.int32(2): 85})
# Test: Counter({np.int32(1): 58, np.int32(0): 44, np.int32(2): 36})

# %%
y_pred = model.predict(imgs_test).argmax(axis=1)
cm = confusion_matrix(labels_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=False, cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
import matplotlib.pyplot as plt

# Predict on test set
preds = model.predict(imgs_test)
pred_labels = np.argmax(preds, axis=1)

# Number of samples to show
num_samples = 10

# Inverse mapping from label to character
inv_encoder = {v: k for k, v in ENCODER.items()}

plt.figure(figsize=(15, 5))

for i in range(num_samples):
    plt.subplot(2, 5, i + 1)
    plt.imshow(imgs_test[i].squeeze(), cmap='gray')
    plt.axis('off')
    
    actual = inv_encoder[labels_test[i]]
    predicted = inv_encoder[pred_labels[i]]
    
    color = 'green' if actual == predicted else 'red'
    plt.title(f"Pred: {predicted}\nTrue: {actual}", color=color)

plt.tight_layout()
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
misclassified = np.where(y_pred != labels_test)[0]
for i in misclassified[:5]:  # show first 5 [:x}
    plt.imshow(imgs_test[i].squeeze(), cmap='gray') 
    
    true_char = ENCODER.inverse[labels_test[i] + 1]
    pred_char = ENCODER.inverse[y_pred[i] + 1]
    
    plt.title(f"True: {true_char}, Pred: {pred_char}")
    plt.axis('off')
    plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 48, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 24, 24, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 24, 24, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 22, 22, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 11, 11, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 7744)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         495,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,544,843 (5.89 MB)
#  Trainable params: 514,883 (1.96 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 1,029,768 (3.93 MB)

# %%
unique, counts = np.unique(labels_train, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Label {u}: {c} samples")
# Out:
# Label 0: 102 samples
# Label 1: 135 samples
# Label 2: 85 samples

# %%
model.save("model_c1.keras")

# %%
print(f"Num classes: {len(np.unique(labels))}")
print(f"Min label: {np.min(labels)}, Max label: {np.max(labels)}")
# Out:
# Num classes: 3
# Min label: 0, Max label: 2

# %%
import collections
print(collections.Counter(labels_train))
# Out:
# Counter({np.int32(1): 135, np.int32(0): 102, np.int32(2): 85})

# %%
for i in range(10):
    sample = imgs_test[i].reshape(1, 50, 50, 1)
    pred = np.argmax(model.predict(sample), axis=-1)[0]
    true = labels_test[i]
    print(f"True: {true}, Pred: {pred}")
